# %%
# !uv pip install -q --system numba-cuda==0.4.0
import numpy as np
from numba import cuda
import time
import os
from numba import config
config.CUDA_ENABLE_PYNVJITLINK = 1

# %%
from numba.cuda.simulator import kernel
# CUDA STEPS:
# Initializing data on CPU
# Transfer from CPU to GPU
# Run Kernel with defined Grid/Block size (threads)
# Transfer results from GPU to CPU
# Clear memory

# CUDA Kernel Device
@cuda.jit
def first_kernel(a,result):
  idx = cuda.grid(1)  # index thread
  if idx < a.size:
    result[idx] = a[idx]

# Host CPU
def main():
  # 1. Initialize data on CPU
  N = 10_000_000
  a_cpu = np.arange(N, dtype=np.float32)


  # ---------------------------------
  # CPU computation
  # ---------------------------------
  start = time.time()
  result_cpu = a_cpu
  cpu_time = time.time() - start
  print(f"CPU time: {cpu_time * 1e6:.2f} us")

  # ---------------------------------
  # GPU computation
  # ---------------------------------
  # 2. Transfer from CPU to GPU
  start = time.time()
  a_gpu = cuda.to_device(a_cpu)
  result_gpu = cuda.device_array_like(a_cpu) # reserve memory
  transfer_in_time = time.time() - start

  # Kernel launch
  threads_per_block = 128
  blocks_per_grid = (N + threads_per_block - 1) // threads_per_block # (10_000_000 + 127) // 128 = 78,125 blocks
  start = time.time()
  first_kernel[blocks_per_grid, threads_per_block](a_gpu, result_gpu) # lunch kernel
  cuda.synchronize()
  kernel_time = time.time() - start

  # Copy back
  start = time.time()
  result_from_gpu = result_gpu.copy_to_host()
  cuda.synchronize()
  transfer_out_time = time.time() - start

  # Report
  print(f"GPU trnasfer to device: {transfer_in_time * 1e3:.2f} ms")
  print(f"GPU kernel execution:   {kernel_time * 1e3:.2f} ms")
  print(f"GPU transfer to host:   {transfer_out_time * 1e3:.2f} ms")
  print(f"TOTAL GPU time:         {(transfer_in_time + kernel_time + transfer_out_time ) * 1e3:.2f} ms")

  # Cleanup
  del a_gpu, result_gpu
  cuda.close()

if __name__ == "__main__":
    main()
# Out:
# CPU time: 1.43 us
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-881438564.py in <cell line: 0>()
#      63
#      64 if __name__ == "__main__":
# ---> 65     main()
#
# /tmp/ipython-input-881438564.py in main()
#      42   blocks_per_grid = (N + threads_per_block - 1) // threads_per_block # (10_000_000 + 127) // 128 = 78,125 blocks
#      43   start = time.time()
# ---> 44   first_kernel[blocks_per_grid, threads_per_block](a_gpu, result_gpu) # lunch kernel
#      45   cuda.synchronize()
#      46   kernel_time = time.time() - start
#
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py in __call__(self, *args)
#     606
#     607     def __call__(self, *args):
# --> 608         return self.dispatcher.call(args, self.griddim, self.blockdim,
#     609                                     self.stream, self.sharedmem)
#     610
#
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py in call(self, args, griddim, blockdim, stream, sharedmem)
#     748             kernel = next(iter(self.overloads.values()))
#     749         else:
# --> 750             kernel = _dispatcher.Dispatcher._cuda_call(self, *args)
#     751
#     752         kernel.launch(args, griddim, blockdim, stream, sharedmem)
#
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py in _compile_for_args(self, *args, **kws)
#     756         assert not kws
#     757         argtypes = [self.typeof_pyval(a) for a in args]
# --> 758         return self.compile(tuple(argtypes))
#     759
#     760     def typeof_pyval(self, val):
#
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py in compile(self, sig)
#    1003             kernel = _Kernel(self.py_func, argtypes, **self.targetoptions)
#    1004             # We call bind to force codegen, so that there is a cubin to cache
# -> 1005             kernel.bind()
#    1006             self._cache.save_overload(sig, kernel)
#    1007
#
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py in bind(self)
#     255         Force binding to current CUDA context
#     256         """
# --> 257         cufunc = self._codelibrary.get_cufunc()
#     258
#     259         if hasattr(self, "target_context") and self.target_context.enable_nrt:
#
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/codegen.py in get_cufunc(self)
#     246             return cufunc
#     247
# --> 248         cubin = self.get_cubin(cc=device.compute_capability)
#     249         module = ctx.create_module_image(cubin)
#     250
#
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/codegen.py in get_cubin(self, cc)
#     220             print('=' * 80)
#     221
# --> 222         linker = driver.Linker.new(
#     223             max_registers=self._max_registers,
#     224             cc=cc,
#
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/cudadrv/driver.py in new(cls, max_registers, lineinfo, cc, lto, additional_flags)
#    2606
#    2607         if linker is PyNvJitLinker:
# -> 2608             return linker(max_registers, lineinfo, cc, lto, additional_flags)
#    2609         elif additional_flags or lto:
#    2610             raise ValueError("LTO and additional flags require PyNvJitLinker")
#
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/cudadrv/driver.py in __init__(self, max_registers, lineinfo, cc, lto, additional_flags)
#    3035     ):
#    3036         if NvJitLinker is None:
# -> 3037             raise ImportError(
#    3038                 "Using pynvjitlink requires the pynvjitlink package to be "
#    3039                 "available"
#
# ImportError: Using pynvjitlink requires the pynvjitlink package to be available
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
